# %%
import cupy as np
x = np.arange(1, 4)
print(x)
# Out:
# [1 2 3]

# %%
import weakref
import gc
a = np.array([1, 2, 3])

# %%
b = weakref.ref(a)
b
# Out:
# <weakref at 0x7b7d183e6f70; to 'ndarray' at 0x7b7d183f8790>

# %%
b()
# Out:
# array([1, 2, 3])

# %%
a = None
gc.collect()
b
# Out:
# <weakref at 0x7b7d183e6f70; to 'ndarray' at 0x7b7d183f8790>
